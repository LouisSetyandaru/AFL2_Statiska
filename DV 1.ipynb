# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
data = {
    "CarBrand": ["Honda", "Honda", "Toyota", "Toyota", "Honda", "Audi", "Audi", "BMW", "BMW", "Mercedes-Benz",
                 "Mercedes-Benz", "Mercedes-Benz", "Volkswagen", "Volkswagen", "Volkswagen", "Volkswagen", "Audi", 
                 "Audi", "Audi", "Mercedes-Benz", "Mercedes-Benz", "Mercedes-Benz", "BMW", "BMW", "BMW", "Ford", 
                 "Ford", "Ford", "Ford", "Jaguar", "Jaguar", "Jaguar", "Audi", "Audi", "Audi", "Porsche", "Porsche", 
                 "Porsche", "Porsche", "Volvo", "Volvo", "Volvo", "Volvo", "Volvo", "Volvo", "Honda", "Honda", "Subaru", 
                 "Subaru", "Subaru", "Subaru", "Mitsubishi", "Mitsubishi", "Mitsubishi", "Mitsubishi", "Hyundai", "Hyundai", 
                 "Hyundai", "Hyundai", "Kia", "Kia", "Kia", "Kia", "Honda", "Honda", "Honda", "Jeep", "Jeep", "Jeep", 
                 "Jeep", "Mazda", "Mazda", "Mazda", "Mazda", "Mazda", "Nissan", "Nissan", "Nissan", "Nissan", "Nissan", 
                 "Nissan", "Hyundai", "Hyundai", "Hyundai", "Kia", "Kia", "Kia", "Kia", "Toyota", "Toyota", "Toyota", 
                 "Toyota", "Toyota", "Toyota", "Lexus", "Lexus", "Lexus", "Lexus", "Lexus", "Lexus", "Lexus", "Infiniti", 
                 "Infiniti", "Infiniti", "Infiniti", "Infiniti", "Genesis", "Genesis", "Genesis", "Mitsubishi", 
                 "Mitsubishi", "Mitsubishi", "Mitsubishi", "Mitsubishi"]
}

# Membuat DataFrame
df = pd.DataFrame(data)

# Menghitung jumlah mobil per merk
car_counts = df['CarBrand'].value_counts()

# Membuat bar plot
plt.figure(figsize=(15, 8))
car_counts.plot(kind='bar', color='blue')
plt.title('Number of Cars by Car Brand')
plt.xlabel('Car Brand')
plt.ylabel('Number of Car')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# # Display the data distribution of Age of Buyer by Location using box plot
# import matplotlib.pyplot as plt
# # Data usia pembeli berdasarkan lokasi
# Brand = ['Honda', 'Toyota', 'Audi', 'BMW', 'Mercedes-Benz', 'Volkswagen', 'Ford', 'Jaguar', 'Porsche', 'Volvo', 'Subaru', 'Mitsubishi', 'Hyundai', 'Kia', 'Jeep','Mazda','Nissan','Lexus','Infiniti','Genesis']
# Honda = [119, 174, 192, 147, 147]
# Toyota = [168, 301, 184, 184, 188, 221, 228, 248]
# Audi= [201, 335, 255, 335, 261, 335, 252, 375, 420]
# BMW= [255, 335, 362, 252, 450, 320, 320, 320, 316, 316, 316, 316]
# MercedesBenz= [463, 147, 335, 340, 450, 250, 368, 382, 381, 302, 416]
# Volkswagen= [123, 160, 187, 320, 316, 316, 316, 316]
# Ford= [150, 250, 320, 121, 182, 120, 134]
# Jaguar= [450, 247, 247]
# Porsche= [296, 330, 330, 316, 316]
# Volvo= [250, 320, 316, 316, 316, 316]
# Subaru= [152, 78, 224, 190, 141]
# Mitsubishi= [280, 180, 295, 160, 180, 106, 203, 311, 300]
# Hyundai= [400, 268, 295, 177, 187, 316, 316, 316, 316]
# Kia= [316, 316, 316, 316]
# Jeep= [252, 375, 420]
# Mazda= [147, 181, 235, 201]
# Nissan= [290, 147, 185, 365, 190]
# Lexus= [141, 280, 180, 295, 400]
# Infiniti= [268, 295, 400]
# Genesis= [177, 187, 316]

# # Menggabungkan data usia pembeli berdasarkan lokasi
# data_brand = ['Honda', 'Toyota', 'Audi', 'BMW', 'MercedesBenz', 'Volkswagen', 'Ford', 'Jaguar', 'Porsche', 'Volvo', 'Subaru', 'Mitsubishi', 'Hyundai', 'Kia', 'Jeep','Mazda','Nissan','Lexus','Infiniti','Genesis']

# # Menghapus list yang kosong dari data_brand
# data_brand = [brand for brand in data_brand if brand]

# # Membuat box plot
# plt.figure(figsize=(15, 8))
# plt.boxplot(data_brand, labels=[brand for brand in Brand if brand])
# plt.title('Box Plot HorsePower berdasarkan Brand')
# plt.xlabel('Car Brand')
# plt.ylabel('Horse Power')
# plt.grid(True)
# plt.xticks(rotation=45)
# plt.show()

import matplotlib.pyplot as plt

# Data HorsePower berdasarkan Brand
Honda = [119, 174, 192, 147, 147]
Toyota = [168, 301, 184, 184, 188, 221, 228, 248]
Audi = [201, 335, 255, 335, 261, 335, 252, 375, 420]
BMW = [255, 335, 362, 252, 450, 320, 320, 320, 316, 316, 316, 316]
MercedesBenz = [463, 147, 335, 340, 450, 250, 368, 382, 381, 302, 416]
Volkswagen = [123, 160, 187, 320, 316, 316, 316, 316]
Ford = [150, 250, 320, 121, 182, 120, 134]
Jaguar = [450, 247, 247]
Porsche = [296, 330, 330, 316, 316]
Volvo = [250, 320, 316, 316, 316, 316]
Subaru = [152, 78, 224, 190, 141]
Mitsubishi = [280, 180, 295, 160, 180, 106, 203, 311, 300]
Hyundai = [400, 268, 295, 177, 187, 316, 316, 316, 316]
Kia = [316, 316, 316, 316]
Jeep = [252, 375, 420]
Mazda = [147, 181, 235, 201]
Nissan = [290, 147, 185, 365, 190]
Lexus = [141, 280, 180, 295, 400]
Infiniti = [268, 295, 400]
Genesis = [177, 187, 316]

# Menggabungkan data HorsePower berdasarkan Brand
data_brand = [Honda, Toyota, Audi, BMW, MercedesBenz, Volkswagen, Ford, Jaguar, Porsche, Volvo, Subaru, Mitsubishi, Hyundai, Kia, Jeep, Mazda, Nissan, Lexus, Infiniti, Genesis]

# Membuat box plot
plt.figure(figsize=(15, 8))
plt.boxplot(data_brand, labels=Brand)
plt.title('Box Plot HorsePower berdasarkan Brand')
plt.xlabel('Car Brand')
plt.ylabel('Horse Power')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data jumlah silinder
total_engine_cylinders = [4, 4, 4, 6, 4, 4, 6, 4, 6, 4,
                          6, 8, 4, 4, 4, 4, 4, 4, 6, 4,
                          4, 4, 4, 4, 6, 3, 4, 4, 8, 4,
                          4, 6, 4, 4, 6, 4, 6, 6, 4, 4,
                          4, 4, 4, 4, 4, 6, 6, 4, 4, 6,
                          4, 6, 4, 4, 4, 4, 4, 6, 4, 4,
                          6, 6, 6, 6, 4, 4, 4, 4, 4, 4,
                          6, 4, 4, 4, 4, 4, 6, 8, 4, 6,
                          4, 4, 6, 4, 6, 8, 4, 6, 4, 4,
                          6, 4, 4, 6, 6, 6, 4, 4, 6, 8,
                          4, 6, 4, 4, 4]

# Menghitung jumlah mobil untuk setiap jumlah silinder
counts = {cylinder: total_engine_cylinders.count(cylinder) for cylinder in set(total_engine_cylinders)}

# Menyiapkan data untuk pie chart
labels = counts.keys()
sizes = counts.values()

# Membuat pie chart
plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Number of Cars Based on Number of Cylinders')
plt.axis('equal')  # Memastikan pie chart berbentuk lingkaran
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the data from CSV and Excel files
# df_csv = pd.read_csv('cars_data.csv')
df_excel = pd.read_excel('cars_data.xlsx')

# Check the column names in the DataFrames
# print("CSV Columns:", df_csv.columns)
print("Excel Columns:", df_excel.columns)

# Assuming the correct column names are 'CarName' and 'HorsePower'
plt.figure(figsize=(15, 8))
sns.barplot(data=df_excel, x='CarName', y='HorsePower', palette='muted')
plt.title('Horsepower of Cars by Name')
plt.xlabel('Car Name')
plt.ylabel('Horsepower')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Excel Columns: Index(['CarName', 'CarBrand', 'TotalEngineCylinders', 'HorsePower', 'Torque',
#        'FuelConsumptionPerLiter', 'TopSpeed', '0To100Kph', 'PriceInRupiah'],
#       dtype='object')
# C:\Users\Louis\AppData\Local\Temp\ipykernel_11056\1853104714.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_excel, x='CarName', y='HorsePower', palette='muted')
